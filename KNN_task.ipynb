# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/MECHINE LEARNING/ML Algorithm/KNN/housing_in_london_monthly_variables.csv')
df.head()
# Out:
#          date            area  average_price       code  houses_sold  \
# 0  1995-01-01  city of london          91449  E09000001         17.0
# 1  1995-02-01  city of london          82203  E09000001          7.0
# 2  1995-03-01  city of london          79121  E09000001         14.0
# 3  1995-04-01  city of london          77101  E09000001          7.0
# 4  1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  borough_flag
# 0           NaN             1
# 1           NaN             1
# 2           NaN             1
# 3           NaN             1
# 4           NaN             1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13549 entries, 0 to 13548
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           13549 non-null  object
#  1   area           13549 non-null  object
#  2   average_price  13549 non-null  int64
#  3   code           13549 non-null  object
#  4   houses_sold    13455 non-null  float64
#  5   no_of_crimes   7439 non-null   float64
#  6   borough_flag   13549 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 741.1+ KB

# %%
df.shape
# Out:
# (13549, 7)

# %%
df.describe()
# Out:
#        average_price    houses_sold  no_of_crimes  borough_flag
# count   1.354900e+04   13455.000000   7439.000000  13549.000000
# mean    2.635197e+05    3893.994129   2158.352063      0.733338
# std     1.876175e+05   12114.402476    902.087742      0.442230
# min     4.072200e+04       2.000000      0.000000      0.000000
# 25%     1.323800e+05     247.000000   1623.000000      0.000000
# 50%     2.229190e+05     371.000000   2132.000000      1.000000
# 75%     3.368430e+05    3146.000000   2582.000000      1.000000
# max     1.463378e+06  132163.000000   7461.000000      1.000000

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for i in df.columns:
  df[i]=le.fit_transform(df[i])

df
# Out:
#        date  area  average_price  code  houses_sold  no_of_crimes  \
# 0         0     6           1853     0           14          2669
# 1         1     6           1485     0            4          2669
# 2         2     6           1338     0           11          2669
# 3         3     6           1272     0            4          2669
# 4         4     6           1605     0            7          2669
# ...     ...   ...            ...   ...          ...           ...
# 13544   296    12           7726    44         3745          2669
# 13545   297    12           7708    44         3766          2669
# 13546   298    12           7680    44         3762          2669
# 13547   299    12           7735    44         3946          2669
# 13548   300    12           7642    44         3946          2669
#
#        borough_flag
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 13544             0
# 13545             0
# 13546             0
# 13547             0
# 13548             0
#
# [13549 rows x 7 columns]

# %%
x = df . iloc[:,:6]

y = df.iloc[: ,-1]

x.head()
# Out:
#    date  area  average_price  code  houses_sold  no_of_crimes
# 0     0     6           1853     0           14          2669
# 1     1     6           1485     0            4          2669
# 2     2     6           1338     0           11          2669
# 3     3     6           1272     0            4          2669
# 4     4     6           1605     0            7          2669

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: borough_flag, dtype: int64

# %%
from sklearn . model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20 ,random_state = 0)

# %%
x_train.head()
# Out:
#        date  area  average_price  code  houses_sold  no_of_crimes
# 12210   165    10           5093    38         1500          2669
# 122     122     6           9329     0           15             0
# 273     273     6          13091     0           14          2669
# 5166     43    20           2240    17          310          2669
# 8541    107    38           5320    28          435           266

# %%
y_train.head()
# Out:
# 12210    0
# 122      1
# 273      1
# 5166     1
# 8541     1
# Name: borough_flag, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sd = StandardScaler()

sd.fit(x_train)
x_train = sd.transform(x_train)

x_test = sd.fit_transform(x_test)

# %%
x_train.shape
# Out:
# (10839, 6)

# %%
y_train.shape
# Out:
# (10839,)

# %% [markdown]
# MODEL BUILDING

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=5)

model.fit(x_train , y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# MODEL PREDICTION

# %%
y_pred = model.predict(x_test)

y_pred
# Out:
# array([0, 1, 1, ..., 1, 1, 0])

# %% [markdown]
# MODEL EVALUATION

# %%
from sklearn.metrics import accuracy_score

score = accuracy_score(y_test,y_pred)

score
# Out:
# 0.9996309963099631
